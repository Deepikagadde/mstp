# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sb

# %%
d = pd.read_csv("iris.csv")

# %%
d.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### 1

# %%
a=d['species'].unique()
a.size
# Out:
# 3

# %% [markdown]
# ### 2

# %%
d.pop('species')
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
# 5         setosa
# 6         setosa
# 7         setosa
# 8         setosa
# 9         setosa
# 10        setosa
# 11        setosa
# 12        setosa
# 13        setosa
# 14        setosa
# 15        setosa
# 16        setosa
# 17        setosa
# 18        setosa
# 19        setosa
# 20        setosa
# 21        setosa
# 22        setosa
# 23        setosa
# 24        setosa
# 25        setosa
# 26        setosa
# 27        setosa
# 28        setosa
# 29        setosa
#          ...
# 120    virginica
# 121    virginica
# 122    virginica
# 123    virginica
# 124    virginica
# 125    virginica
# 126    virginica
# 127    virginica
# 128    virginica
# 129    virginica
# 130    virginica
# 131    virginica
# 132    virginica
# 133    virginica
# 134    virginica
# 135    virginica
# 136    virginica
# 137    virginica
# 138    virginica
# 139    virginica
# 140    virginica
# ...

# %%
x=d.max()
y=d.mean()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### 3.

# %%
import matplotlib.pyplot as plt

# %%
b=d['sepal_length'].values
c=d['petal_width'].values
plt.title("scatter plot")
plt.xlabel("sepal_length")
plt.ylabel("petal_length")

plt.scatter(b,c)
plt.show()

# %% [markdown]
# #### 4

# %%
b=d['sepal_length'].values
c=d['petal_width'].values
plt.title("bargraph plot")
plt.xlabel("sepal_length")
plt.ylabel("petal_length")

plt.bar(b,c)
plt.show()

# %% [markdown]
# ### 5

# %%
sb.jointplot(d['sepal_length'],d['sepal_width'],data=d)

# %% [markdown]
# ### 6

# %%
sb.FacetGrid?

# %%
a=sb.load_dataset('iris')

# %%
a.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sb.FacetGrid(a, col="sepal_length",  row="sepal_width",hue='species')

# %% [markdown]
# ### 7.

# %%
sb.boxplot(d['species'],d['sepal_width'],data=d)

# %% [markdown]
# ### 8

# %%
sb.boxplot(d['species'],d['sepal_length'],data=d,hue='species')

# %%
sb.stripplot(d['species'],d['sepal_width'],data=d,hue='species')

# %% [markdown]
# ### 9

# %%
sb.violinplot(d['petal_length'],d['species'],data=d)

# %% [markdown]
# ### 10

# %%
sb.pairplot(d,hue='species')
